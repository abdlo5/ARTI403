# %% [markdown]
# #lask 1

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread("cameraman.tif")

plt.imshow(img, cmap='gray')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       2 import matplotlib.pyplot as plt
#       4 img = cv2.imread("cameraman.tif")
# ----> 6 plt.imshow(img, cmap='gray')
#       7 plt.show()
#
# File c:\Users\qabdu\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:3601, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, colorizer, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    3579 @_copy_docstring_and_deprecators(Axes.imshow)
#    3580 def imshow(
#    3581     X: ArrayLike | PIL.Image.Image,
#    (...)   3599     **kwargs,
#    3600 ) -> AxesImage:
# -> 3601     __ret = gca().imshow(
#    3602         X,
#    3603         cmap=cmap,
#    3604         norm=norm,
#    3605         aspect=aspect,
#    3606         interpolation=interpolation,
# ...

# %% [markdown]
# #task2

# %%
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.cm as cm
img2=Image.open("fabio_gray_512.tif")
plt.imshow(img2, cmap= cm.gray_r)
plt.show()

# %% [markdown]
# #task3

# %%
cv2.imwrite("cameraman.jpg",img)
# Out:
# True

# %% [markdown]
# #task4

# %%
img2.save("fabio_gray_512.jpg")

# %% [markdown]
# #task5

# %%
print(img.shape)
print(img)
# Out:
# (256, 256, 3)
# [[[156 156 156]
#   [159 159 159]
#   [158 158 158]
#   ...
#   [151 151 151]
#   [152 152 152]
#   [152 152 152]]
#
#  [[160 160 160]
#   [154 154 154]
#   [157 157 157]
#   ...
#   [154 154 154]
#   [155 155 155]
#   [153 153 153]]
#
#  [[156 156 156]
#   [159 159 159]
#   [158 158 158]
#   ...
#   [151 151 151]
#   [152 152 152]
#   [152 152 152]]
#
#  ...
#
#  [[114 114 114]
#   [132 132 132]
#   [123 123 123]
#   ...
#   [135 135 135]
#   [137 137 137]
#   [114 114 114]]
#
#  [[121 121 121]
#   [126 126 126]
#   [130 130 130]
#   ...
#   [133 133 133]
#   [130 130 130]
#   [113 113 113]]
#
#  [[121 121 121]
#   [126 126 126]
#   [130 130 130]
#   ...
#   [133 133 133]
#   [130 130 130]
#   [113 113 113]]]
